# %%
! python inference.py --config_path=/home/mazheng/waste-detection/Yet-Another-EfficientDet-Pytorch/inference_tool/config/config.yml
# Out:
# 2022-05-15 01:45:43.721479625 [W:onnxruntime:, graph.cc:3559 CleanUnusedInitializersAndNodeArgs] Removing initializer 'backbone_net.model._blocks.16._bn2.num_batches_tracked'. It is not used by any node and should be removed from the model.
# 2022-05-15 01:45:43.721572355 [W:onnxruntime:, graph.cc:3559 CleanUnusedInitializersAndNodeArgs] Removing initializer 'classifier.bn_list.0.1.num_batches_tracked'. It is not used by any node and should be removed from the model.
# 2022-05-15 01:45:43.721603175 [W:onnxruntime:, graph.cc:3559 CleanUnusedInitializersAndNodeArgs] Removing initializer 'bifpn.4.conv3_up.bn.num_batches_tracked'. It is not used by any node and should be removed from the model.
# 2022-05-15 01:45:43.721667835 [W:onnxruntime:, graph.cc:3559 CleanUnusedInitializersAndNodeArgs] Removing initializer 'backbone_net.model._blocks.0._bn2.num_batches_tracked'. It is not used by any node and should be removed from the model.
# ...

# %%
! python inference_video.py --config_path=/home/mazheng/waste-detection/Yet-Another-EfficientDet-Pytorch/inference_tool/config/config_video.yml
